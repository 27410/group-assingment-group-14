# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
#%pip install cobra

# %%
#%pip install memote

# %%
from cobra.io import read_sbml_model, write_sbml_model
from cobra import Reaction, Metabolite

# %%
iMM1366 =  read_sbml_model('Data\iJO1366.xml')
iMM1366
# Out:
# <Model iJO1366 at 0x240b4963100>

# %%
# !memote report snapshot Data/iJO1366.xml
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.13, pytest-7.1.2, pluggy-1.0.0
# rootdir: c:\Users\Candela
# plugins: anyio-3.5.0
# collected 146 items / 1 skipped
#
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py . [  0%]
# .FFFFFFFFF..FFFFFFFFFFFFFFFFFFFFFF.FF..F...FFFF.FFFFFFFF..FFFF..         [ 44%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py .. [ 45%]
# ..F.FF.......F.....FF                                                    [ 60%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py . [ 60%]
# F....FF.F                                                                [ 67%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py . [ 67%]
# ..ssssssssssssssssFFFFFF.FFF                                             [ 86%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_essentiality.py s [ 87%]
#                                                                          [ 87%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_growth.py s [ 88%]
#                                                                          [ 88%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_matrix.py . [ 89%]
# ...                                                                      [ 91%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbml.py ..  [ 92%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py FF.. [ 95%]
# .F.Fss.                                                                  [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\lib\site-packages\_pytest\config\__init__.py:1129
#   c:\Users\Candela\anaconda3\lib\site-packages\_pytest\config\__init__.py:1129: PytestAssertRewriteWarning: Module already imported so cannot be rewritten: anyio
#     self._mark_plugins_for_rewrite(hook)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# =========================== short test summary info ===========================
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[pubchem.compound]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[kegg.compound]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[seed.compound]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[inchikey]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[inchi]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[chebi]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[hmdb]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[reactome]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[biocyc]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[rhea]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[kegg.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[seed.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[metanetx.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[bigg.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[reactome]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[ec-code]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[brenda]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[biocyc]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[refseq]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[uniprot]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[ecogene]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[kegg.genes]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[ncbigi]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[ncbigene]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[ncbiprotein]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[ccds]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[hprd]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[asap]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_wrong_ids[pubchem.compound]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_wrong_ids[kegg.compound]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_wrong_ids[inchikey]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_wrong_ids[inchi]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_wrong_ids[reactome]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[rhea]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[kegg.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[seed.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[metanetx.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[reactome]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[ec-code]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[brenda]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[biocyc]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[refseq]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[uniprot]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[ecogene]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[kegg.genes]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[ncbiprotein]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[ccds]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[hprd]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[asap]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py::test_metabolites_formula_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py::test_gene_protein_reaction_rule_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py::test_ngam_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py::test_transport_reaction_gpr_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py::test_find_reactions_with_identical_genes
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py::test_find_medium_metabolites
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py::test_biomass_consistency[BIOMASS_SC5_notrace]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py::test_gam_in_biomass[BIOMASS_SC5_notrace]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py::test_fast_growth_default[BIOMASS_SC5_notrace]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py::test_essential_precursors_not_in_biomass[BIOMASS_SC5_notrace]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_reaction_charge_balance
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_reaction_mass_balance
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_blocked_reactions
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_stoichiometrically_balanced_cycles
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_orphans
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_deadends
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_metabolites_not_produced_with_open_bounds
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_metabolites_not_consumed_with_open_bounds
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_reactions_unbounded_flux_default_condition
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_metabolite_sbo_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_reaction_sbo_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_metabolite_specific_sbo_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_exchange_specific_sbo_presence
# ====== 73 failed, 53 passed, 21 skipped, 1 warning in 234.94s (0:03:54) =======
# El sistema no puede encontrar la ruta especificada.
# The current solver interface glpk doesn't support setting the optimality tolerance.
# Writing snapshot report to 'index.html'.
# ============================= test session starts =============================
# platform win32 -- Python 3.9.13, pytest-7.1.2, pluggy-1.0.0
# rootdir: c:\Users\Candela
# plugins: anyio-3.5.0
# collected 155 items / 1 skipped
#
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py . [  0%]
# .FFFFFFFFF..FFFFFFFFFFFFFFFFFFFFFF.FF..F...FFFF.FFFFF..F..FFF...         [ 41%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py .. [ 43%]
# ....F..............FF                                                    [ 56%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py . [ 57%]
# ............FF..FF                                                       [ 69%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py . [ 69%]
# ..ssssssssssssssss..FFFF.FFF                                             [ 87%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_essentiality.py s [ 88%]
#                                                                          [ 88%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_growth.py s [ 89%]
#                                                                          [ 89%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_matrix.py . [ 89%]
# ...                                                                      [ 91%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbml.py ..  [ 92%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py FF.. [ 95%]
# .F.FFs.                                                                  [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\lib\site-packages\_pytest\config\__init__.py:1129
#   c:\Users\Candela\anaconda3\lib\site-packages\_pytest\config\__init__.py:1129: PytestAssertRewriteWarning: Module already imported so cannot be rewritten: anyio
#     self._mark_plugins_for_rewrite(hook)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# =========================== short test summary info ===========================
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[pubchem.compound]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[kegg.compound]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[seed.compound]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[inchikey]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[inchi]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[chebi]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[hmdb]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[reactome]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[biocyc]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[rhea]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[kegg.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[seed.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[metanetx.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[bigg.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[reactome]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[ec-code]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[brenda]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[biocyc]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[refseq]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[uniprot]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[ecogene]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[kegg.genes]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[ncbigi]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[ncbigene]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[ncbiprotein]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[ccds]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[hprd]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[asap]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_wrong_ids[pubchem.compound]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_wrong_ids[kegg.compound]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_wrong_ids[inchikey]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_wrong_ids[inchi]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_wrong_ids[reactome]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[rhea]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[kegg.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[seed.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[metanetx.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[reactome]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[ec-code]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[brenda]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[biocyc]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[refseq]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[kegg.genes]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[ncbiprotein]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[ccds]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[hprd]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py::test_gene_protein_reaction_rule_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py::test_find_reactions_with_identical_genes
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py::test_find_medium_metabolites
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py::test_fast_growth_default[BIOMASS_Ec_iJO1366_WT_53p95M]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py::test_fast_growth_default[BIOMASS_Ec_iJO1366_core_53p95M]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py::test_essential_precursors_not_in_biomass[BIOMASS_Ec_iJO1366_WT_53p95M]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py::test_essential_precursors_not_in_biomass[BIOMASS_Ec_iJO1366_core_53p95M]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_blocked_reactions
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_stoichiometrically_balanced_cycles
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_orphans
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_deadends
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_metabolites_not_produced_with_open_bounds
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_metabolites_not_consumed_with_open_bounds
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_reactions_unbounded_flux_default_condition
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_metabolite_sbo_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_reaction_sbo_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_metabolite_specific_sbo_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_exchange_specific_sbo_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_demand_specific_sbo_presence
# ====== 66 failed, 70 passed, 20 skipped, 1 warning in 297.99s (0:04:57) =======
# El sistema no puede encontrar la ruta especificada.
# The current solver interface glpk doesn't support setting the optimality tolerance.
# Writing snapshot report to 'index.html'.

# %%
iMM1515 =  read_sbml_model('Data\iML1515.xml')
iMM1515
# Out:
# <Model iML1515 at 0x240bb2c2af0>

# %%
# !memote report snapshot Data/iML1515.xml
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.13, pytest-7.1.2, pluggy-1.0.0
# rootdir: c:\Users\Candela
# plugins: anyio-3.5.0
# collected 155 items / 1 skipped
#
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py . [  0%]
# ..FFFFFFFFF.FFFFF.FFFFFFFFFFFFFFF..FF..F...F....FFF.F..FF.FFF...         [ 41%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py .. [ 43%]
# ....F............F.FF                                                    [ 56%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py . [ 57%]
# ..F...F.....FF..FF                                                       [ 69%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py . [ 69%]
# ..ssssssssssssssss.FFFFF.FFF                                             [ 87%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_essentiality.py s [ 88%]
#                                                                          [ 88%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_growth.py s [ 89%]
#                                                                          [ 89%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_matrix.py . [ 89%]
# ...                                                                      [ 91%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbml.py ..  [ 92%]
# ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py FFFF [ 95%]
# FFFFFs.                                                                  [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\lib\site-packages\_pytest\config\__init__.py:1129
#   c:\Users\Candela\anaconda3\lib\site-packages\_pytest\config\__init__.py:1129: PytestAssertRewriteWarning: Module already imported so cannot be rewritten: anyio
#     self._mark_plugins_for_rewrite(hook)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# =========================== short test summary info ===========================
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[pubchem.compound]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[kegg.compound]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[seed.compound]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[inchikey]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[inchi]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[chebi]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[hmdb]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[reactome]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[metanetx.chemical]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_overview[biocyc]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[rhea]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[kegg.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[seed.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[metanetx.reaction]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[reactome]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[ec-code]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[brenda]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_overview[biocyc]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[refseq]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[uniprot]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[ecogene]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[kegg.genes]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[ncbigi]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[ncbigene]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[ncbiprotein]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[ccds]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[hprd]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_overview[asap]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_wrong_ids[pubchem.compound]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_wrong_ids[inchikey]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_wrong_ids[inchi]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_metabolite_annotation_wrong_ids[reactome]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[rhea]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[reactome]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[ec-code]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_reaction_annotation_wrong_ids[brenda]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[refseq]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[kegg.genes]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[ncbigi]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[ncbiprotein]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[ccds]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_annotation.py::test_gene_product_annotation_wrong_ids[hprd]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py::test_gene_protein_reaction_rule_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py::test_find_reactions_with_partially_identical_annotations
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py::test_find_reactions_with_identical_genes
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_basic.py::test_find_medium_metabolites
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py::test_biomass_default_production[BIOMASS_Ec_iML1515_WT_75p37M]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py::test_biomass_precursors_default_production[BIOMASS_Ec_iML1515_WT_75p37M]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py::test_fast_growth_default[BIOMASS_Ec_iML1515_WT_75p37M]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py::test_fast_growth_default[BIOMASS_Ec_iML1515_core_75p37M]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py::test_essential_precursors_not_in_biomass[BIOMASS_Ec_iML1515_WT_75p37M]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_biomass.py::test_essential_precursors_not_in_biomass[BIOMASS_Ec_iML1515_core_75p37M]
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_reaction_mass_balance
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_blocked_reactions
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_stoichiometrically_balanced_cycles
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_orphans
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_deadends
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_metabolites_not_produced_with_open_bounds
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_metabolites_not_consumed_with_open_bounds
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_consistency.py::test_find_reactions_unbounded_flux_default_condition
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_metabolite_sbo_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_reaction_sbo_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_gene_sbo_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_metabolic_reaction_specific_sbo_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_transport_reaction_specific_sbo_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_metabolite_specific_sbo_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_gene_specific_sbo_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_exchange_specific_sbo_presence
# FAILED ..\..\..\anaconda3\lib\site-packages\memote\suite\tests\test_sbo.py::test_demand_specific_sbo_presence
# ====== 69 failed, 67 passed, 20 skipped, 1 warning in 301.26s (0:05:01) =======
# El sistema no puede encontrar la ruta especificada.
# The current solver interface glpk doesn't support setting the optimality tolerance.
# Writing snapshot report to 'index.html'.
